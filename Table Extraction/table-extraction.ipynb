# %% [markdown]
# ## Extract Table from website

# %%
import pandas as pd

# %%
simpsons = pd.read_html('https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)')
len(simpsons)
# Out:
# 24

# %%
simpsons[2]
# Out:
#     No. overall  No. in season  \
# 0          14.0            1.0
# 1          15.0            2.0
# 2          16.0            3.0
# 3          16.0            3.0
# 4          16.0            3.0
# 5           NaN            NaN
# 6          17.0            4.0
# 7          18.0            5.0
# 8          19.0            6.0
# 9          20.0            7.0
# 10         21.0            8.0
# 11         22.0            9.0
# 12         23.0           10.0
# 13         24.0           11.0
# 14         25.0           12.0
# 15         26.0           13.0
# 16         27.0           14.0
# 17         28.0           15.0
# 18         29.0           16.0
# 19         30.0           17.0
# 20         31.0           18.0
# 21         32.0           19.0
# 22         33.0           20.0
# 23         34.0           21.0
# 24         35.0           22.0
#
#                                                 Title      Directed by  \
# ...

# %%
gpuPerformance = pd.read_html('https://www.tomshardware.com/reviews/gpu-hierarchy,4388.html')
len(gpuPerformance)

print(gpuPerformance[1])
# Out:
#                Graphics Card       1080p Medium        1080p Ultra  \
# 0           GeForce RTX 4090  100.0% (159.9fps)  100.0% (132.7fps)
# 1           GeForce RTX 4080   83.1% (132.9fps)   78.9% (104.8fps)
# 2        GeForce RTX 3090 Ti   71.6% (114.5fps)    65.3% (86.7fps)
# 3        GeForce RTX 4070 Ti   71.6% (114.4fps)    64.8% (86.0fps)
# 4           GeForce RTX 3090   67.3% (107.6fps)    59.3% (78.7fps)
# 5         Radeon RX 7900 XTX   67.2% (107.5fps)    60.0% (79.7fps)
# 6        GeForce RTX 3080 Ti   65.7% (105.0fps)    57.7% (76.6fps)
# 7      GeForce RTX 3080 12GB   64.5% (103.1fps)    56.5% (75.0fps)
# 8          Radeon RX 7900 XT    60.9% (97.4fps)    53.2% (70.5fps)
# 9           GeForce RTX 4070    60.7% (97.2fps)    52.3% (69.4fps)
# 10          GeForce RTX 3080    59.3% (94.8fps)    51.7% (68.7fps)
# 11       GeForce RTX 3070 Ti    50.1% (80.2fps)    42.1% (55.8fps)
# 12         Radeon RX 6950 XT    50.1% (80.1fps)    42.5% (56.4fps)
# ...

# %% [markdown]
# ## Reading CSV file
#
# This url contains multiple excel files which we can download
# https://www.football-data.co.uk/englandm.php

# %%
epl23 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2324/E0.csv')
print(epl23)
# Out:
#     Div        Date   Time     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  11/08/2023  20:00      Burnley       Man City     0     3   A     0
# 1    E0  12/08/2023  12:30      Arsenal  Nott'm Forest     2     1   H     2
# 2    E0  12/08/2023  15:00  Bournemouth       West Ham     1     1   D     0
# 3    E0  12/08/2023  15:00     Brighton          Luton     4     1   H     1
# 4    E0  12/08/2023  15:00      Everton         Fulham     0     1   A     0
# ..   ..         ...    ...          ...            ...   ...   ...  ..   ...
# 198  E0  12/01/2024  19:45      Burnley          Luton     1     1   D     1
# 199  E0  13/01/2024  12:30      Chelsea         Fulham     1     0   H     1
# 200  E0  13/01/2024  17:30    Newcastle       Man City     2     3   A     2
# 201  E0  14/01/2024  14:00      Everton    Aston Villa     0     0   D     0
# 202  E0  14/01/2024  16:30   Man United      Tottenham     2     2   D     2
#
# ...

# %% [markdown]
# ### Rename Columns

# %%
epl23.rename(columns={'FTHG': 'Home Goals', 
                      'FTAG': 'Away Goals' }, inplace = True)

# %% [markdown]
# ### Show DataFrame

# %%
epl23
# Out:
#     Div        Date   Time     HomeTeam       AwayTeam  Home Goals  \
# 0    E0  11/08/2023  20:00      Burnley       Man City           0
# 1    E0  12/08/2023  12:30      Arsenal  Nott'm Forest           2
# 2    E0  12/08/2023  15:00  Bournemouth       West Ham           1
# 3    E0  12/08/2023  15:00     Brighton          Luton           4
# 4    E0  12/08/2023  15:00      Everton         Fulham           0
# ..   ..         ...    ...          ...            ...         ...
# 198  E0  12/01/2024  19:45      Burnley          Luton           1
# 199  E0  13/01/2024  12:30      Chelsea         Fulham           1
# 200  E0  13/01/2024  17:30    Newcastle       Man City           2
# 201  E0  14/01/2024  14:00      Everton    Aston Villa           0
# 202  E0  14/01/2024  16:30   Man United      Tottenham           2
#
#      Away Goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# 0             3   A     0     2  ...     2.28  1.50      1.95      1.98
# ...

# %% [markdown]
# ## Extract Tables from PDF

# %%
import camelot

# %%
tables = camelot.read_pdf('foo.pdf', pages='1')
print(tables)
# Out:
# <TableList n=1>

# %% [markdown]
# ### Save Table to CSV File

# %%
tables.export('foo.csv', f='csf', compress=True)
tables[0].to_csv('foo.csv')
